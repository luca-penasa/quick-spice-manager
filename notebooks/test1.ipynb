# %%
import quick_spice_manager

# %%
from quick_spice_manager.spice_manager import QuickSpiceManager

man = QuickSpiceManager()
tc = man.tour_config

man.load_kernels()

man.config
# Out:
# /tmp/ipykernel_320377/2531900779.py:4: DeprecationWarning: QuickSpiceManager.tour_config (property) is deprecated and will be removed in a future release. Use get_tour_config() instead.
#   tc = man.tour_config
#                                                          value
# key
# spacecraft                                               JUICE
# version                                                 latest
# metakernel   /data/.cache/quick-spice-manager/kernels/juice...
# kernels_dir     /data/.cache/quick-spice-manager/kernels/juice

# %%
traj = tc["2025-01-01T00:00:00":"2026-01-01T00:00:00":'1 day']

traj.angular_size('callisto')
# Out:
# array([0.00038054, 0.00037917, 0.0003778 , 0.00037639, 0.0003749 ,
#        0.00037329, 0.00037157, 0.00036973, 0.0003678 , 0.00036581,
#        0.00036382, 0.00036188, 0.00036002, 0.00035829, 0.0003567 ,
#        0.00035524, 0.00035392, 0.00035269, 0.00035151, 0.00035036,
#        0.00034918, 0.00034795, 0.00034664, 0.00034524, 0.00034376,
#        0.00034223, 0.00034068, 0.00033914, 0.00033766, 0.00033628,
#        0.00033502, 0.00033388, 0.00033288, 0.00033199, 0.00033119,
#        0.00033044, 0.0003297 , 0.00032895, 0.00032814, 0.00032727,
#        0.00032632, 0.0003253 , 0.00032424, 0.00032317, 0.00032211,
#        0.00032111, 0.0003202 , 0.00031939, 0.0003187 , 0.00031813,
#        0.00031766, 0.00031726, 0.0003169 , 0.00031654, 0.00031616,
#        0.00031574, 0.00031524, 0.00031467, 0.00031403, 0.00031336,
#        0.00031266, 0.00031198, 0.00031136, 0.00031081, 0.00031037,
#        0.00031003, 0.00030979, 0.00030965, 0.00030956, 0.00030951,
# ...

# %%
man.config
# Out:
#                                                          value
# key
# spacecraft                                               JUICE
# version                                                 latest
# metakernel   /data/.cache/quick-spice-manager/kernels/juice...
# kernels_dir     /data/.cache/quick-spice-manager/kernels/juice

# %%
man.cache_size
# Out:
# '1.4 GiB'

# %%
man.metakernels
# Out:
# ['juice_crema_5_0',
#  'juice_crema_5_0_v471_20260708_001',
#  'juice_crema_5_0b23_1',
#  'juice_crema_5_0b23_1_v471_20260708_001',
#  'juice_crema_5_1_150la',
#  'juice_crema_5_1_150la_v471_20260708_001',
#  'juice_crema_5_1_150lb_23_1',
#  'juice_crema_5_1_150lb_23_1_a3',
#  'juice_crema_5_1_150lb_23_1_a3_2',
#  'juice_crema_5_1_150lb_23_1_a3_2_v471_20260708_001',
#  'juice_crema_5_1_150lb_23_1_a3_v471_20260708_001',
#  'juice_crema_5_1_150lb_23_1_b2',
#  'juice_crema_5_1_150lb_23_1_b2_v471_20260708_001',
#  'juice_crema_5_1_150lb_23_1_v471_20260708_001',
#  'juice_crema_5_2',
#  'juice_crema_5_2_3G3to14C7_8E2lat',
#  'juice_crema_5_2_3G3to14C7_8E2lat_V3',
#  'juice_crema_5_2_3G3to14C7_8E2lat_V3_v471_20260708_001',
#  'juice_crema_5_2_v471_20260708_001',
#  'juice_crema_kallichore',
#  'juice_crema_kallichore_v471_20260708_001',
#  'juice_gco500_option_23',
#  'juice_gco500_option_23_v471_20260708_001',
#  'juice_gco500_option_32',
#  'juice_gco500_option_32_v471_20260708_001',
# ...

# %%
import spiceypy

# %%
spiceypy.kclear()
spiceypy.furnsh(str(man.resolved_mk))
